# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plot

# %%
data = pd.read_csv(r"C:\Users\Dhruv Kumar Jha\Downloads\COVIDdata.csv")

# %%
data = data[~(data['Cases - cumulative total'] == 68165877)]

# %%
data.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 1  United States of America         Americas                  14972356
# 2                     India  South-East Asia                   9767371
# 3                    Brazil         Americas                   6674999
# 4        Russian Federation           Europe                   2541199
# 5                    France           Europe                   2269668
#
#    Cases - cumulative total per 1 million population  \
# 1                                           45233.34
# 2                                            7077.78
# 3                                           31402.98
# 4                                           17413.29
# 5                                           34771.65
#
#    Cases - newly reported in last 7 days  \
# 1                                1408625
# 2                                 232407
# 3                                 288212
# 4                                 193798
# ...

# %%
data.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 1 million population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 1 million population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 24 hours',
#        'Transmission Classification'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Cases - cumulative total  \
# count              2.350000e+02
# mean               2.900676e+05
# std                1.278154e+06
# min                0.000000e+00
# 25%                8.655000e+02
# 50%                1.205800e+04
# 75%                1.225960e+05
# max                1.497236e+07
#
#        Cases - cumulative total per 1 million population  \
# count                                         234.000000
# mean                                        12606.192308
# std                                         15762.239156
# min                                             0.000000
# 25%                                           580.117500
# 50%                                          5112.340000
# 75%                                         20466.557500
# max                                         92240.990000
#
#        Cases - newly reported in last 7 days  \
# count                           2.350000e+02
# mean                            1.823814e+04
# ...

# %%
data.isnull()
# Out:
#       Name  WHO Region  Cases - cumulative total  \
# 1    False       False                     False
# 2    False       False                     False
# 3    False       False                     False
# 4    False       False                     False
# 5    False       False                     False
# ..     ...         ...                       ...
# 231  False       False                     False
# 232  False       False                     False
# 233  False       False                     False
# 234  False       False                     False
# 235  False       False                     False
#
#      Cases - cumulative total per 1 million population  \
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# 5                                                False
# ...

# %%
data.isnull().sum()
# Out:
# Name                                                  0
# WHO Region                                            0
# Cases - cumulative total                              0
# Cases - cumulative total per 1 million population     1
# Cases - newly reported in last 7 days                 0
# Cases - newly reported in last 24 hours               0
# Deaths - cumulative total                             0
# Deaths - cumulative total per 1 million population    1
# Deaths - newly reported in last 7 days                0
# Deaths - newly reported in last 24 hours              0
# Transmission Classification                           0
# dtype: int64

# %% [markdown]
# ## Playing with ScatterPlots!

# %%
data.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 1  United States of America         Americas                  14972356
# 2                     India  South-East Asia                   9767371
# 3                    Brazil         Americas                   6674999
# 4        Russian Federation           Europe                   2541199
# 5                    France           Europe                   2269668
#
#    Cases - cumulative total per 1 million population  \
# 1                                           45233.34
# 2                                            7077.78
# 3                                           31402.98
# 4                                           17413.29
# 5                                           34771.65
#
#    Cases - newly reported in last 7 days  \
# 1                                1408625
# 2                                 232407
# 3                                 288212
# 4                                 193798
# ...

# %%
sb.relplot(x="Cases - cumulative total per 1 million population", y="Deaths - cumulative total per 1 million population", data = data)

# %%
sb.pairplot(data)

# %%
sb.relplot(x="Cases - cumulative total", y="Deaths - cumulative total", data = data)

# %% [markdown]
# ### Total region wise confirmed & Death cases :

# %%
data.groupby('WHO Region').sum()
# Out:
#                        Cases - cumulative total  \
# WHO Region
# Africa                                  1571911
# Americas                               29139394
# Eastern Mediterranean                   4408403
# Europe                                 20869839
# Other                                       744
# South-East Asia                        11237814
# Western Pacific                          937772
#
#                        Cases - cumulative total per 1 million population  \
# WHO Region
# Africa                                                         119080.19
# Americas                                                       733850.97
# Eastern Mediterranean                                          326731.51
# Europe                                                        1602165.77
# Other                                                               0.00
# South-East Asia                                                 49016.78
# ...

# %%
data.groupby('WHO Region')['Cases - cumulative total'].sum().sort_values(ascending = False)
# Out:
# WHO Region
# Americas                 29139394
# Europe                   20869839
# South-East Asia          11237814
# Eastern Mediterranean     4408403
# Africa                    1571911
# Western Pacific            937772
# Other                         744
# Name: Cases - cumulative total, dtype: int64

# %%
data.groupby('WHO Region')['Deaths - cumulative total'].sum().sort_values(ascending = False)
# Out:
# WHO Region
# Americas                 760908
# Europe                   462615
# South-East Asia          170924
# Eastern Mediterranean    109878
# Africa                    34979
# Western Pacific           18068
# Other                        13
# Name: Deaths - cumulative total, dtype: int64

# %%
data.groupby('WHO Region')['Cases - cumulative total', 'Deaths - cumulative total'].sum()
# Out:
# C:\Users\Dhruv Kumar Jha\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        Cases - cumulative total  Deaths - cumulative total
# WHO Region
# Africa                                  1571911                      34979
# Americas                               29139394                     760908
# Eastern Mediterranean                   4408403                     109878
# Europe                                 20869839                     462615
# Other                                       744                         13
# South-East Asia                        11237814                     170924
# Western Pacific                          937772                      18068

# %%
data.tail()
# Out:
#              Name       WHO Region  Cases - cumulative total  \
# 231         Samoa  Western Pacific                         0
# 232       Tokelau  Western Pacific                         0
# 233         Tonga  Western Pacific                         0
# 234  Turkmenistan           Europe                         0
# 235        Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 1 million population  \
# 231                                                0.0
# 232                                                0.0
# 233                                                0.0
# 234                                                0.0
# 235                                                0.0
#
#      Cases - newly reported in last 7 days  \
# 231                                      0
# 232                                      0
# 233                                      0
# 234                                      0
# ...

# %% [markdown]
# ### Deleting data of below certain number :

# %%
data = data[~(data['Cases - cumulative total'] <= 10)]

# %%
data.tail()
# Out:
#                             Name       WHO Region  Cases - cumulative total  \
# 212                    Greenland           Europe                        18
# 213  Falkland Islands (Malvinas)         Americas                        17
# 214              Solomon Islands  Western Pacific                        17
# 215    Saint Pierre and Miquelon         Americas                        14
# 216                   Montserrat         Americas                        13
#
#      Cases - cumulative total per 1 million population  \
# 212                                             317.06
# 213                                            4880.85
# 214                                              24.75
# 215                                            2415.88
# 216                                            2600.52
#
#      Cases - newly reported in last 7 days  \
# 212                                      0
# 213                                      0
# ...

# %%
data.head(20)
# Out:
#                           Name             WHO Region  \
# 1     United States of America               Americas
# 2                        India        South-East Asia
# 3                       Brazil               Americas
# 4           Russian Federation                 Europe
# 5                       France                 Europe
# 6                        Italy                 Europe
# 7           The United Kingdom                 Europe
# 8                        Spain                 Europe
# 9                    Argentina               Americas
# 10                    Colombia               Americas
# 11                     Germany                 Europe
# 12                      Mexico               Americas
# 13                      Poland                 Europe
# 14  Iran (Islamic Republic of)  Eastern Mediterranean
# 15                        Peru               Americas
# 16                      Turkey                 Europe
# ...

# %% [markdown]
# ### Dataset of INDIA :

# %%
data[data.Name == 'India']
# Out:
#     Name       WHO Region  Cases - cumulative total  \
# 2  India  South-East Asia                   9767371
#
#    Cases - cumulative total per 1 million population  \
# 2                                            7077.78
#
#    Cases - newly reported in last 7 days  \
# 2                                 232407
#
#    Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 2                                    31521                     141772
#
#    Deaths - cumulative total per 1 million population  \
# 2                                             102.73
#
#    Deaths - newly reported in last 7 days  \
# 2                                    3124
#
#    Deaths - newly reported in last 24 hours Transmission Classification
# 2                                       412           Clusters of cases

# %% [markdown]
# ### Sort:

# %%
data.sort_values(by = ['Deaths - cumulative total'], ascending = False)
# Out:
#                                  Name       WHO Region  \
# 1            United States of America         Americas
# 3                              Brazil         Americas
# 2                               India  South-East Asia
# 12                             Mexico         Americas
# 7                  The United Kingdom           Europe
# ..                                ...              ...
# 203                          Dominica         Americas
# 202  Saint Vincent and the Grenadines         Americas
# 185                     Faroe Islands           Europe
# 196                        Seychelles           Africa
# 190                          Cambodia  Western Pacific
#
#      Cases - cumulative total  \
# 1                    14972356
# 3                     6674999
# 2                     9767371
# 12                    1193255
# 7                     1750245
# ..                        ...
# 203                        85
# 202                        90
# ...

# %%
data[~(data['Deaths - cumulative total']<10)]
# Out:
#                             Name       WHO Region  Cases - cumulative total  \
# 2                          India  South-East Asia                   9767371
# 3                         Brazil         Americas                   6674999
# 4             Russian Federation           Europe                   2541199
# 5                         France           Europe                   2269668
# 6                          Italy           Europe                   1757394
# ..                           ...              ...                       ...
# 179                        Other            Other                       744
# 186  United Republic of Tanzania           Africa                       509
# 187                    Mauritius           Africa                       505
# 189                  Isle of Man           Europe                       370
# 194                     Guernsey           Europe                       288
#
# ...

# %%
data['Cases - cumulative total'].plot(kind = 'hist')

# %%
data['Cases - cumulative total per 1 million population'].plot(kind = 'hist')

# %%
plot.scatter(data['Cases - cumulative total per 1 million population'], data['Deaths - cumulative total per 1 million population'], color='r')
plot.scatter(data['Cases - newly reported in last 7 days'], data['Deaths - newly reported in last 7 days'], color='g')
plot.scatter(data['Cases - newly reported in last 24 hours'], data['Deaths - newly reported in last 24 hours'], color='b')
plot.title('All correlations')
plot.xlabel('Cases')
plot.ylabel('Deaths')
plot.show()

# %% [markdown]
# ### For zooming the plot, we'll exclude America for once

# %%
data = data[~(data['WHO Region'] == 'Americas')]

# %%
data.head(2)
# Out:
#                  Name       WHO Region  Cases - cumulative total  \
# 2               India  South-East Asia                   9767371
# 4  Russian Federation           Europe                   2541199
#
#    Cases - cumulative total per 1 million population  \
# 2                                            7077.78
# 4                                           17413.29
#
#    Cases - newly reported in last 7 days  \
# 2                                 232407
# 4                                 193798
#
#    Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 2                                    31521                     141772
# 4                                    26190                      44718
#
#    Deaths - cumulative total per 1 million population  \
# 2                                             102.73
# 4                                             306.43
#
#    Deaths - newly reported in last 7 days  \
# 2                                    3124
# ...

# %%
plot.scatter(data['Cases - cumulative total per 1 million population'], data['Deaths - cumulative total per 1 million population'], color='r')
plot.scatter(data['Cases - newly reported in last 7 days'], data['Deaths - newly reported in last 7 days'], color='g')
plot.scatter(data['Cases - newly reported in last 24 hours'], data['Deaths - newly reported in last 24 hours'], color='b')
plot.title('All correlations')
plot.xlabel('Cases')
plot.ylabel('Deaths')
plot.show()
